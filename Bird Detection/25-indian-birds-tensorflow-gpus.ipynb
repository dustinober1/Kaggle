# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Define the number of classes
num_classes = 25

# %%
train_ds = keras.preprocessing.image_dataset_from_directory(
    "/kaggle/input/25-indian-bird-species-with-226k-images/training_set",
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(224, 224),
    batch_size=32,
)

val_ds = keras.preprocessing.image_dataset_from_directory(
    "/kaggle/input/25-indian-bird-species-with-226k-images/training_set",
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(224, 224),
    batch_size=32,
)
# Out:
# Found 22620 files belonging to 25 classes.
# Using 18096 files for training.
# Found 22620 files belonging to 25 classes.
# Using 4524 files for validation.

# %%
# Create the model
model = keras.Sequential([
    layers.experimental.preprocessing.Rescaling(1./255),
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes)
])

# %%
# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Train the model
model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)
# Out:
# Epoch 1/10
# 566/566 [==============================] - 272s 461ms/step - loss: 2.7266 - accuracy: 0.2194 - val_loss: 2.1637 - val_accuracy: 0.3720
# Epoch 2/10
# 566/566 [==============================] - 263s 460ms/step - loss: 1.6351 - accuracy: 0.5297 - val_loss: 1.7694 - val_accuracy: 0.5038
# Epoch 3/10
# 566/566 [==============================] - 225s 393ms/step - loss: 0.8540 - accuracy: 0.7510 - val_loss: 2.2662 - val_accuracy: 0.4894
# Epoch 4/10
# 566/566 [==============================] - 224s 392ms/step - loss: 0.3357 - accuracy: 0.8988 - val_loss: 2.7999 - val_accuracy: 0.5111
# Epoch 5/10
# 566/566 [==============================] - 225s 393ms/step - loss: 0.1645 - accuracy: 0.9515 - val_loss: 3.0960 - val_accuracy: 0.5150
# Epoch 6/10
# 566/566 [==============================] - 262s 459ms/step - loss: 0.1201 - accuracy: 0.9642 - val_loss: 3.7077 - val_accuracy: 0.5177
# Epoch 7/10
# 566/566 [==============================] - 262s 458ms/step - loss: 0.0998 - accuracy: 0.9720 - val_loss: 3.6636 - val_accuracy: 0.5057
# Epoch 8/10
# 566/566 [==============================] - 224s 392ms/step - loss: 0.0788 - accuracy: 0.9773 - val_loss: 4.0610 - val_accuracy: 0.4945
# Epoch 9/10
# 566/566 [==============================] - 225s 393ms/step - loss: 0.0765 - accuracy: 0.9784 - val_loss: 4.1477 - val_accuracy: 0.5190
# Epoch 10/10
# 566/566 [==============================] - 224s 391ms/step - loss: 0.0621 - accuracy: 0.9811 - val_loss: 4.0946 - val_accuracy: 0.5069

# %%
# Save the model
model.save("/kaggle/working/GPU_Model.h5")
