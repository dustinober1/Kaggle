# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt

# %%
train_data_dir = '/kaggle/input/cats-in-the-wild-image-classification/train'
val_data_dir = '/kaggle/input/cats-in-the-wild-image-classification/valid'
test_data_dir = '/kaggle/input/cats-in-the-wild-image-classification/test'

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(150, 150),
    batch_size=128,
    class_mode='categorical',
    classes=['AFRICAN LEOPARD', 'CARACAL', 'CHEETAH', 'CLOUDED LEOPARD', 'JAGUAR', 'LION', 'OCELOT', 'PUMA', 'SNOW LEOPARD', 'TIGER'])

validation_generator = test_datagen.flow_from_directory(
    val_data_dir,
    target_size=(150, 150),
    batch_size=128,
    class_mode='categorical',
    classes=['AFRICAN LEOPARD', 'CARACAL', 'CHEETAH', 'CLOUDED LEOPARD', 'JAGUAR', 'LION', 'OCELOT', 'PUMA', 'SNOW LEOPARD', 'TIGER'])

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(150, 150),
    batch_size=128,
    class_mode='categorical',
    classes=['AFRICAN LEOPARD', 'CARACAL', 'CHEETAH', 'CLOUDED LEOPARD', 'JAGUAR', 'LION', 'OCELOT', 'PUMA', 'SNOW LEOPARD', 'TIGER'])
# Out:
# Found 2111 images belonging to 10 classes.
# Found 45 images belonging to 10 classes.
# Found 45 images belonging to 10 classes.

# %%
# Create a convolutional neural network (CNN) model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# Train the model using the train and validation sets
history = model.fit(train_generator,
                    steps_per_epoch=10,
                    epochs=15,
                    validation_data=validation_generator,
                    validation_steps=10,
                    verbose=1)
# Save the model
model.save('/kaggle/working/my_model.h5')
# Out:
# Epoch 1/15
# 10/10 [==============================] - 41s 4s/step - loss: 0.1222 - accuracy: 0.9594 - val_loss: 1.5269 - val_accuracy: 0.6667
# Epoch 2/15
# 10/10 [==============================] - 39s 4s/step - loss: 0.1091 - accuracy: 0.9613
# Epoch 3/15
# 10/10 [==============================] - 39s 4s/step - loss: 0.1344 - accuracy: 0.9506
# Epoch 4/15
# 10/10 [==============================] - 39s 4s/step - loss: 0.1335 - accuracy: 0.9498
# Epoch 5/15
# 10/10 [==============================] - 40s 4s/step - loss: 0.1365 - accuracy: 0.9625
# Epoch 6/15
# 10/10 [==============================] - 39s 4s/step - loss: 0.1270 - accuracy: 0.9498
# Epoch 7/15
# 10/10 [==============================] - 38s 4s/step - loss: 0.1454 - accuracy: 0.9481
# Epoch 8/15
# 10/10 [==============================] - 39s 4s/step - loss: 0.1383 - accuracy: 0.9457
# Epoch 9/15
# 10/10 [==============================] - 38s 4s/step - loss: 0.1510 - accuracy: 0.9449
# Epoch 10/15
# 10/10 [==============================] - 41s 4s/step - loss: 0.1319 - accuracy: 0.9516
# Epoch 11/15
# 10/10 [==============================] - 39s 4s/step - loss: 0.1116 - accuracy: 0.9564
# Epoch 12/15
# 10/10 [==============================] - 41s 4s/step - loss: 0.1549 - accuracy: 0.9453
# Epoch 13/15
# 10/10 [==============================] - 39s 4s/step - loss: 0.1393 - accuracy: 0.9605
# Epoch 14/15
# 10/10 [==============================] - 39s 4s/step - loss: 0.1211 - accuracy: 0.9564
# Epoch 15/15
# 10/10 [==============================] - 38s 4s/step - loss: 0.1185 - accuracy: 0.9564
